# %% [markdown]
# <a href="https://colab.research.google.com/github/vaibhav2005vk-cloud/Python-numpy-pandas-matplotlib-EDA/blob/main/Day15_numpy_Linear/class_notes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Day 15 Numpy Linear Algebra

# %% [markdown]
# Linear Algebra is the mathematical foundation of Machine Learning. Algorithms like Linear Regression, PCA, Neural Networks, and Transformers rely heavily on matrix operations.

# %% [markdown]
# 1. import numpy

# %%
import numpy as np

# %% [markdown]
# 2. create matrix

# %%
import numpy as np
a = np.array([
    [1,2],
    [3,4]
])
b = np.array([
    [5,6],
    [7,8]
])
print(a)
print(b)
# Out:
# [[1 2]
#  [3 4]]
# [[5 6]
#  [7 8]]

# %% [markdown]
# 3. Matrux Addition

# %%
print(a+b)

# %% [markdown]
# Output

# %% [markdown]
# [[ 6  8]
#  [10 12]

# %% [markdown]
# 4. Matrix Subtraction

# %%
print(a-b)

# %% [markdown]
# 5. Matrix Multiplication

# %% [markdown]
# using np.dot():

# %%
print(np.dot(a,b))

# %% [markdown]
# Using @ operator

# %%
print(a@b)

# %% [markdown]
# 6. Matrix transpose

# %%
print(a.T)

# %% [markdown]
# or

# %%
print(np.transpose(a))

# %% [markdown]
# 7. Determinat

# %%
print(np.linalg.det(a))

# %% [markdown]
# 8. Matrix inverse

# %%
print(np.linalg.inv(a))

# %% [markdown]
# 9. Matrix rank

# %%
print(np.linalg.matrix_rank(a))

# %% [markdown]
# 10. Trace of a matrix

# %%
print(np.trace(a))

# %% [markdown]
# 11. Eigenvalues & Eigenvectors

# %%
values, vectors = np.linalg.eig(A)

print("Eigenvalues:")
print(values)

print("Eigenvectors:")
print(vectors)

# %% [markdown]
# 12. Slove a system of Equations

# %% [markdown]
# slove :
# ° x+y = 5
# ° 2x + 3y = 13

# %%
import numpy as np
a = np.array([
    [1,1],
    [2,3]
])
b = np.array([5,13])
print(np.linalg.solve(a,b))
# Out:
# [2. 3.]

# %% [markdown]
# 13. Matrix Norm

# %%
print(np.linalg.norm(A))

# %% [markdown]
# 14. Identiy Matrix

# %%
I = np.eye(3)

print(I)
