# %% [markdown]
# <a href="https://colab.research.google.com/github/vaibhav2005vk-cloud/Python-numpy-pandas-matplotlib-EDA/blob/main/Day3_String/Pratice%20set.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pratice Question

# %% [markdown]
# 1. Print your full name

# %%
name = "Vaibhav" #string
print(name)
# Out:
# Vaibhav

# %% [markdown]
# 2. Print the first and last character

# %%
text = "Deep Learning "
print(text[0]) # first character
print(text[1]) # second character
# Out:
# D
# e

# %% [markdown]
# 3. Reverse your name

# %%
a = "vaibhav"[::-1] # Reverse the name
print(a)
# Out:
# vahbiav

# %% [markdown]
# 4.Count vowels in string

# %%
name = "vaibhav"
print(name.count("a")) #count vowels
# Out:
# 2

# %% [markdown]
# 5. Replace every space with _

# %%
txt = " Artificial intelligence "
print(txt.replace(" ","_"))
# Out:
# _Artificial_intelligence_

# %% [markdown]
# 6. Cinvert a sentence into uppercase

# %%
name = "vaibhav"
print(name.upper()) #uppercase
# Out:
# VAIBHAV

# %% [markdown]
# 7. Convert a sentence  to a lowecase

# %%
txt = "I AM ML ENGINEER "
print(txt.lower()) # lowercase
# Out:
# i am ml engineer

# %% [markdown]
# 9. Split "Python,NumPy,Pandas" into a list.

# %%
txt = "Python,NumPy,Pandas"
print(txt.split(","))
# Out:
# ['Python', 'NumPy', 'Pandas']
