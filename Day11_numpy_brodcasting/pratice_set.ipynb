# %% [markdown]
# <a href="https://colab.research.google.com/github/vaibhav2005vk-cloud/Python-numpy-pandas-matplotlib-EDA/blob/main/Day11_numpy_brodcasting/pratice_set.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pratice Question

# %% [markdown]
# 1. Add 5 to every element of an array

# %%
import numpy as np
arr = np.array([10,20,30,40])
print(arr+5)
# Out:
# [15 25 35 45]

# %% [markdown]
# 2. Multiply every element by 2

# %%
import numpy as np
arr = np.array([10,20,30])
print(arr*2)
# Out:
# [20 40 60]

# %% [markdown]
# 3. Divide every element by 2

# %%
import numpy as np

arr = np.array([
    [10, 20, 30],
    [40, 50, 60]
])
print(arr / 2)
# Out:
# [[ 5. 10. 15.]
#  [20. 25. 30.]]

# %% [markdown]
# 4. Add  two 1D arrays

# %%
import numpy as np
arr1 = np.array([1,2,3,4])
arr2 = ([5,6,7,8])
print(arr1+arr2)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %% [markdown]
# 5. Add a row vector to a 2D matrix

# %%
import numpy as np
matrix = np.array([[1,2,3],[4,5,6]])
row = np.array([10,20,30])
print(matrix +row)
# Out:
# [[11 22 33]
#  [14 25 36]]

# %% [markdown]
# 7.Multiple a matrix by 3

# %%
import numpy as np
matrix = np.array([[1,2,3],[4,5,6]])
print(matrix*3)
# Out:
# [[ 3  6  9]
#  [12 15 18]]

# %% [markdown]
# 8. create a 2d matrix and add them

# %%
import numpy as np
arr1 = np.array([[1,2,3],[4,5,6]])
arr2 = np.array([[1,2,3],[4,5,6]])
print(arr1+arr2)
# Out:
# [[ 2  4  6]
#  [ 8 10 12]]
