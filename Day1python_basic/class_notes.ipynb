# %% [markdown]
# <a href="https://colab.research.google.com/github/vaibhav2005vk-cloud/Python-numpy-pandas-matplotlib-EDA/blob/main/Day1python_basic/class_notes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Out:
# hay

# %% [markdown]
# Frist python program

# %%
print("hay")
# Out:
# hay

# %% [markdown]
# Variables

# %%
name = "Vaibhav"
age = 21
height = 5.10
is_student = True

# %% [markdown]
# Type checking

# %%
type(a)
type(b)

# %% [markdown]
# Input Output

# %%
name = input("enter the name")
print(name)
# Out:
# enter the nameVaibhav
# Vaibhav

# %% [markdown]
# Basic Practice

# %%
print("vaibhav")
age = 21
print(type(age))
a = int(input("enter the no"))
b = int(input("enter the no"))
print(a+b)
# Out:
# vaibhav
# <class 'int'>
# enter the no10
# enter the no40
# 50
