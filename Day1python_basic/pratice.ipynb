# %% [markdown]
# <a href="https://colab.research.google.com/github/vaibhav2005vk-cloud/Python-numpy-pandas-matplotlib-EDA/blob/main/Day1python_basic/pratice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Out:
# hay

# %% [markdown]
# Today assignment

# %% [markdown]
# 1. print your name age and city

# %%
name = "vaibhav"
age = 21
city = "Lucknow"
print(name)
print(age)
print(city)
# Out:
# vaibhav
# 21
# Lucknow

# %% [markdown]
# 2. Create all variables data type

# %%
name = "Vaibhav"
age = 18
height = 5.10
is_student = True
print(type(name))
print(type(age))
print(type(height))
print(type(is_student))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %% [markdown]
# 3. Take Two number of user and print
#   ° Sum
#   ° Subtract
#   ° Multiply
#   ° Divide

# %%
a = int(input("Enter the no :"))
b = int(input("Enter the no :" ))
print(a+b)
print(a-b)
print(a*b)
print(a/b)
# Out:
# Enter the no :10
# Enter the no :10
# 20
# 0
# 100
# 1.0
