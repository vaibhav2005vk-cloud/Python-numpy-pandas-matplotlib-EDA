# %% [markdown]
# <a href="https://colab.research.google.com/github/vaibhav2005vk-cloud/Python-numpy-pandas-matplotlib-EDA/blob/main/Day19_pandas_filtering/class_notes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Day 19  Data Selection & Filtering

# %% [markdown]
# 1. Create a DataFrame

# %%
import pandas as pd
data ={
    "Name" : ["Abhay","Vaibhav","Ayush","Aryan"],
    "Age" : [24,21,15,13],
    "Marks" : [90,98,78,87],
    "City" : ["Mumbai","Dehli","Kanpur","unnao"]
}
df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age  Marks    City
# 0    Abhay   24     90  Mumbai
# 1  Vaibhav   21     98   Dehli
# 2    Ayush   15     78  Kanpur
# 3    Aryan   13     87   unnao

# %% [markdown]
# 2. Select one columns

# %%
print(df["Marks"])

# %% [markdown]
# 3. Select Mulitiple Columns

# %%
print(df[["Name","Marks"]])

# %% [markdown]
# 4. Select Row with iloc

# %%
print(df.iloc[o])

# %% [markdown]
# First three row

# %%
print(df.iloc[0:3])

# %% [markdown]
# 6. Filter student with marks

# %%
print(df[df["Marks >80"]])

# %% [markdown]
# Filter student with city

# %%
print(df[df["City" == "unnao"]])

# %% [markdown]
# 8. Multiple  Condition

# %%
print(df[(df["Marks"] > 80) & (df["Age"] > 18)])

# %% [markdown]
# 9. Multiple condition with (|)

# %%
print(df[(df["city"] =="Dehli")|(df["City"]== "unnao")])

# %% [markdown]
# 10.  Sort by marks

# %%
print(df.sort_values(by=="Marks"))

# %% [markdown]
# Descending

# %%
print(df.sort_values(by = "Marks", ascending = False))

# %% [markdown]
# 11. Top 3 student

# %%
top = df.sort_values(by = "Marks").head(2)
print(top)

# %% [markdown]
# Bottom 2 student

# %%
bottom = df.sort_values(by = "Marks").tail(2)
print(bottom)
