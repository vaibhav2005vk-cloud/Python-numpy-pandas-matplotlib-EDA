# %% [markdown]
# <a href="https://colab.research.google.com/github/vaibhav2005vk-cloud/Python-numpy-pandas-matplotlib-EDA/blob/main/Day4_List/pratice_set.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 💻 Practice Questions

# %% [markdown]
# 1. Create a list of five numbers.

# %%
num = [1,2,3,4,5]
print(num)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# 2. Print the first, last, and middle element.

# %%
num =[1,2,3,4,5]
print(num[0])
print(num[2])
print(num[4])
# Out:
# 1
# 3
# 5

# %% [markdown]
# 3. Add a new element.

# %%
furit = ["apple","banana","gauava"]
furit.append("orange")
print(furit)
# Out:
# ['apple', 'banana', 'gauava', 'orange']

# %% [markdown]
# 4. Remove an element.

# %%
furits = ["apple","banana","gauva","orange"]
furits.remove("orange")
print(furits)
# Out:
# ['apple', 'banana', 'gauva']

# %% [markdown]
# 5. sort the list

# %%
num = [1,2,33,4,5,6]
num.sort()
print(num)
# Out:
# [1, 2, 4, 5, 6, 33]

# %% [markdown]
# 6. Reverse the list

# %%
num = [1,2,3,4,5]
num.reverse()
print(num)
# Out:
# [5, 4, 3, 2, 1]

# %% [markdown]
# 7.Count number

# %%
num =[1,2,2,2,3,4]
print(num.count(2))
# Out:
# 3

# %% [markdown]
# 8. Find index of a element

# %%
num = [1,2,3,4]
print(num.index(1))
# Out:
# 0

# %% [markdown]
# 9. Print each element using a loop.

# %%
furits = ["apple","banana","orange"]
for  furit in furits:
  print(furit)
# Out:
# apple
# banana
# orange

# %% [markdown]
# 10. Create a list of squares from 1–20 using list comprehension.

# %%
square = [x*x for x in range(1,21)]
print(square)
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100, 121, 144, 169, 196, 225, 256, 289, 324, 361, 400]
