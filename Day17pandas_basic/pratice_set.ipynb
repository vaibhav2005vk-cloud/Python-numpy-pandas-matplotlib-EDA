# %% [markdown]
# <a href="https://colab.research.google.com/github/vaibhav2005vk-cloud/Python-numpy-pandas-matplotlib-EDA/blob/main/Day17pandas_basic/pratice_set.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Partice Question

# %% [markdown]
# 1. Create a Series with 5 numbers.
# 2. Print the first and last element.
# 3. Create a Series with custom indexes.
# 4. Find the sum and mean.f
# 5. Find the maximum and minimum.
# 6. Multiply every element by 10.
# 7. Add 5 to every element.
# 8. Filter values greater than 50.

# %%
import pandas as pd
marks = pd.Series([80,85,65,56,45],
index= ["Rahul","priya","vaibhav","AYUSH","Aryan"])
print(marks[0])
print(marks[4])
print(marks)
print(marks.sum())
print(marks.mean())
print(marks.max())
print(marks.min())
print(marks*10)
print(marks+5)
print(marks[marks>70])
# Out:
# 80
# 45
# Rahul      80
# priya      85
# vaibhav    65
# AYUSH      56
# Aryan      45
# dtype: int64
# 331
# 66.2
# 85
# 45
# Rahul      800
# priya      850
# vaibhav    650
# AYUSH      560
# Aryan      450
# dtype: int64
# Rahul      85
# priya      90
# vaibhav    70
# AYUSH      61
# Aryan      50
# dtype: int64
# Rahul    80
# priya    85
# dtype: int64
# /tmp/ipykernel_473/2116015550.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(marks[0])
# /tmp/ipykernel_473/2116015550.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(marks[4])
