# %% [markdown]
# <a href="https://colab.research.google.com/github/vaibhav2005vk-cloud/Python-numpy-pandas-matplotlib-EDA/blob/main/Day18_pandas_dataframe/class_notes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Day 18 Pandas Dataframe

# %% [markdown]
# What is dataframe

# %%
DataFrame is a 2-dimensional table with rows and columns.
Example:
Name
Age
Marks
Rahul
20
85
Priya
21
90
Aman
19
78

# %% [markdown]
# 1. import  pandas

# %%
import pandas as pd

# %% [markdown]
# 2. create a data from a dictionary

# %%
import pandas as pd
data = {
    "name" : ["vaibhav","Abhay","Ayush"],
    "age" : [25,21,19]
}
df = pd.DataFrame(data)
print(df)
# Out:
#       name  age
# 0  vaibhav   25
# 1    Abhay   21
# 2    Ayush   19

# %% [markdown]
# 3. check shape

# %%
print(df.shape())

# %% [markdown]
# 4. check coloumns name

# %%
print(df.columns)

# %% [markdown]
# 5. check data type

# %%
print(df.dtype)

# %% [markdown]
# 6. View first row

# %%
print(df.head())

# %% [markdown]
# frist two row

# %%
print(df.head(2))

# %% [markdown]
# 7. View last row

# %%
print(df.tail)

# %% [markdown]
# 8. Select one column

# %%
print(df["Marks"])

# %% [markdown]
# 9. Select multiple column

# %%
print(df[["Name","Marks"]])

# %%
10. Add a new column

# %%
df["Grade"] = ["B","A","c"]
print(df)

# %% [markdown]
# 11. Delete a column

# %%
df.drop("Grade",axis=1,inplace = True)
print(df)

# %% [markdown]
# 12. Acces row using iloc

# %%
print(df.iloc[3])
