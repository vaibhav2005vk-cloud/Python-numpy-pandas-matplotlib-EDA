# %% [markdown]
# <a href="https://colab.research.google.com/github/vaibhav2005vk-cloud/Python-numpy-pandas-matplotlib-EDA/blob/main/Day2python_operator%26%20expression/pratice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Pratice Question

# %% [markdown]
# 1. Take two number as input and perform arthmatic operation

# %%
a = int(input("Enter the no:")) # first input
b = int(input("Enter the no:")) # second input
#Arthmatic opeartion
print(a+b) # Arthmatic
print(a-b) # Subtraction
print(a*b) # Multipliaction
print(a/b) # Division
print(a//b)# Floor Division
print(a%b) # Modulus
# Out:
# Enter the no:50
# Enter the no:30
# 80
# 20
# 1500
# 1.6666666666666667
# 1
# 20

# %% [markdown]
# 2. Compare the two number using all comparison operator

# %%
a = 20 # First number
b = 10 # Second number
print(a==b) # Equal
print(a!=b) # Not equal
print(a>b) # Greater than
print(a<b) # Less than
print(a>=b) # Greater equal than
print(a<=b) # Less Equal than
# Out:
# False
# True
# True
# False
# True
# False

# %% [markdown]
#  3. Check if a number is even or odd with using %

# %%
a = int(input("Enter the no:")) #userinput
# use if condition to chek number is even or odd
result = "even" if a %2 ==0 else "odd"
print(result)
# Out:
# Enter the no:13
# odd
