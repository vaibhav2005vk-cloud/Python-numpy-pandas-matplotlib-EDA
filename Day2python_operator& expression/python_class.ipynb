# %% [markdown]
# <a href="https://colab.research.google.com/github/vaibhav2005vk-cloud/Python-numpy-pandas-matplotlib-EDA/blob/main/Day2python_operator%26%20expression/python_class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Day 2 : Python Operator & Expression

# %% [markdown]
# 1. Arithmetic Operators

# %%
a = 50
b = 30
print(a + b)   # Addition
print(a - b)   # Subtraction
print(a * b)   # Multiplication
print(a / b)   # Division
print(a // b)  # Floor Division
print(a % b)   # Modulus
# Out:
# 80
# 20
# 1500
# 1.6666666666666667
# 1
# 20

# %% [markdown]
# 2.Comphrasion Operator

# %%
a = 10
b = 20

print(a == b)
print(a != b)
print(a > b)
print(a < b)
print(a >= b)
print(a <= b)
# Out:
# False
# True
# False
# True
# False
# True

# %% [markdown]
# 3. Assignment Operators

# %%
x = 10

x += 5
x -= 2
x *= 3
x /= 2

print(x)
# Out:
# 19.5

# %% [markdown]
# 4. Logical Operator

# %%
a = True
b = False
print(a and b)
print(a or b )
print(not a)
# Out:
# False
# True
# False

# %% [markdown]
# 5.memebership Operator

# %%
fruits = ["apple","banana","Orange"]
print("apple" in fruits)
# Out:
# True

# %% [markdown]
# 6. Identify Operator

# %%
a = [1,2]
b = a
c = [1,2]
print(a is b)
print(a is c)
print(a == c)
# Out:
# True
# False
# True
